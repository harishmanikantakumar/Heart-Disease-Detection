# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("C:/Users/Manikata/OneDrive/Desktop/heart.csv")
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
data.shape
# Out:
# (303, 14)

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
data.sample(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1     37    1   2       130   250    0        1      187      0      3.5
# 239   35    1   0       126   282    0        0      156      1      0.0
# 96    62    0   0       140   394    0        0      157      0      1.2
# 105   68    0   2       120   211    0        0      115      0      1.5
# 242   64    1   0       145   212    0        0      132      0      2.0
# 137   62    1   1       128   208    1        0      140      0      0.0
# 272   67    1   0       120   237    0        1       71      0      1.0
# 37    54    1   2       150   232    0        0      165      0      1.6
# 177   64    1   2       140   335    0        1      158      0      0.0
# 234   70    1   0       130   322    0        0      109      0      2.4
#
#      slope  ca  thal  target
# 1        0   0     2       1
# 239      2   0     3       0
# 96       1   0     2       1
# 105      1   0     2       1
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
print(data.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target      1.000000
# exang       0.436757
# cp          0.433798
# oldpeak     0.430696
# thalach     0.421741
# ca          0.391724
# slope       0.345877
# thal        0.344029
# sex         0.280937
# age         0.225439
# trestbps    0.144931
# restecg     0.137230
# chol        0.085239
# fbs         0.028046
# Name: target, dtype: float64

# %%
print(data.corr()["fbs"].abs().sort_values(ascending=False))
# Out:
# fbs         1.000000
# trestbps    0.177531
# ca          0.137979
# age         0.121308
# cp          0.094444
# restecg     0.084189
# slope       0.059894
# sex         0.045032
# thal        0.032019
# target      0.028046
# exang       0.025665
# chol        0.013294
# thalach     0.008567
# oldpeak     0.005747
# Name: fbs, dtype: float64

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
data["sex"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
gender=data.drop(["fbs"],axis=1)

# %%
gender.head()
# Out:
#    age  sex  cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope  ca  \
# 0   63    1   3       145   233        0      150      0      2.3      0   0
# 1   37    1   2       130   250        1      187      0      3.5      0   0
# 2   41    0   1       130   204        0      172      0      1.4      2   0
# 3   56    1   1       120   236        1      178      0      0.8      2   0
# 4   57    0   0       120   354        1      163      1      0.6      2   0
#
#    thal  target
# 0     1       1
# 1     2       1
# 2     2       1
# 3     2       1
# 4     2       1

# %%
#relationship analysis

# %%
corelation=gender.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(gender)
# Out:
# d:\Users\Manikata\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data)
# Out:
# d:\Users\Manikata\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.replot(x="sex",y="target",hue="oldpeak",data=gender)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sns.replot(x="sex",y="target",hue="oldpeak",data=gender)
#
# AttributeError: module 'seaborn' has no attribute 'replot'

# %%
sns.histplot(gender["sex"])
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.distplot(gender["sex"])
# Out:
# C:\Users\Manikata\AppData\Local\Temp\ipykernel_9812\1230139129.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(gender["sex"])
# <Axes: xlabel='sex', ylabel='Density'>

# %%
gender.head()
# Out:
#    age  sex  cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope  ca  \
# 0   63    1   3       145   233        0      150      0      2.3      0   0
# 1   37    1   2       130   250        1      187      0      3.5      0   0
# 2   41    0   1       130   204        0      172      0      1.4      2   0
# 3   56    1   1       120   236        1      178      0      0.8      2   0
# 4   57    0   0       120   354        1      163      1      0.6      2   0
#
#    thal  target
# 0     1       1
# 1     2       1
# 2     2       1
# 3     2       1
# 4     2       1

# %%
sns.replot(x="trestbps",y="chol",hue="restecg",data=gender)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sns.replot(x="trestbps",y="chol",hue="restecg",data=gender)
#
# AttributeError: module 'seaborn' has no attribute 'replot'

# %%
sns.catplot(x="trestbps",kind="box",data=gender)
# Out:
# d:\Users\Manikata\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(x="sex",data=gender)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(y="age",data=gender)
# Out:
# <Axes: xlabel='count', ylabel='age'>

# %%
male_people=len(data[data["sex"]==1])
female_people=len(data[data["sex"]==0])
print("number of msle_people",male_people)
print("number of femsle_peoplr",female_people)
# Out:
# number of msle_people 207
# number of femsle_peoplr 96

# %%
data.head
data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
demo=sns.countplot(x="sex",hue="age",data=data)
demo.axes.set_title("age group",fontsize=30)
demo.set_xlabel("age",fontsize=20)
demo.set_ylabel("count",fontsize=20)
plt.show()

# %%
sns.countplot(x="age",hue="sex",data=gender)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
sns.stripplot(data["chol"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 2
#       1 sns.stripplot(data["chol"])
# ----> 2 sns.axes.set_title("graph",font=30)
#
# AttributeError: module 'seaborn' has no attribute 'axes'

# %%
sns.boxplot(data["age"])
# Out:
# <Axes: >

# %%
sns.barplot(data["sex"])
# Out:
# <Axes: >

# %%
sns.countplot(data["target"])
# Out:
# <Axes: ylabel='count'>

# %%
sns.pointplot(data["target"])
# Out:
# <Axes: >

# %%
sns.lmplot(x="sex",y="target",data=data)
# Out:
# d:\Users\Manikata\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data["sex"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.barplot(data["sex"],data["target"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 sns.barplot(data["sex"],data["target"])
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
count_female=[]

# %%
from platform import python_version
print(python_version())
# Out:
# 3.11.5
